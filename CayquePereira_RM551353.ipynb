# %% [markdown]
# <a href="https://colab.research.google.com/github/Pereira19z/1tdspzReact/blob/main/CayquePereira_RM551353.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Checkpoint 1:
#
# ## Parte 1: (usar como base a aula 1 DataFrame)
#   - Importar as bibliotecas iniciais necessárias;
#   - Importar a base de dados que deseja utilizar;
#   - Exibir informações sobre a base;
#   - Alterar ou carregar os cabeçalhos da base com as seguintes colunas respectivamente: metros do apartamento, quatidade de quartos, quantidade de vagas de garagem, valor em milhares de reais, classe A, B, C ou D);
#   - Exibir as novas informações da base (os primeiros 5 registros e os 5 últimos registros);
#   - Plotar gráficos dos atributos da base carregada;
#   - Calcular as correlações e plotar em gráfico;

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/apartamento-full.csv")

# %%
df.head()
# Out:
#    45  1  0  227  D
# 0  50  1  0  239  D
# 1  50  1  0  270  D
# 2  50  1  0  180  D
# 3  51  1  0  249  D
# 4  51  1  0  249  D
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['45'].plot(kind='hist', bins=20, title='45')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['227'].plot(kind='hist', bins=20, title='227')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='45', y='227', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
# ...

# %% [markdown]
# ## Parte 2: (usar como base a aula 2 KNN)
#   - Carregar as bibliotecas para validação cruzada;
#   - Carregar e utilizar o classificador k-nearest neighbours (kNN);
#   - Apresentar a técnica de separação de dados (treino e teste);
#   - Avaliar Aprendizagem do modelo;

# %%
header = ["coluna1", "coluna2", "coluna3", "coluna4", "coluna5"]  # Substitua pelas colunas reais
df = pd.read_csv("/content/apartamento-full.csv", header=None, names=header)

# %%
df.head()
# Out:
#    coluna1  coluna2  coluna3  coluna4 coluna5
# 0       45        1        0      227       D
# 1       50        1        0      239       D
# 2       50        1        0      270       D
# 3       50        1        0      180       D
# 4       51        1        0      249       D

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   coluna1  102 non-null    int64
#  1   coluna2  102 non-null    int64
#  2   coluna3  102 non-null    int64
#  3   coluna4  102 non-null    int64
#  4   coluna5  102 non-null    object
# dtypes: int64(4), object(1)
# memory usage: 4.1+ KB

# %%
df.shape
# Out:
# (102, 5)

# %%
df.describe()
# Out:
#          coluna1     coluna2     coluna3     coluna4
# count  102.00000  102.000000  102.000000  102.000000
# mean    81.04902    2.764706    1.686275  411.558824
# std     27.13858    1.064052    1.014551  168.454393
# min     45.00000    1.000000    0.000000  180.000000
# 25%     58.25000    2.000000    1.000000  270.000000
# 50%     71.00000    3.000000    1.500000  358.000000
# 75%    103.75000    3.000000    3.000000  538.750000
# max    156.00000    5.000000    3.000000  865.000000

# %%
print(df.columns)
# Out:
# Index(['coluna1', 'coluna2', 'coluna3', 'coluna4', 'coluna5'], dtype='object')

# %%
df.index.unique()
# Out:
# RangeIndex(start=0, stop=102, step=1)

# %%
df = df.set_index(['coluna1', 'coluna2', 'coluna3', 'coluna4', 'coluna5'])
result = df.groupby(level=['coluna1', 'coluna2', 'coluna3', 'coluna4', 'coluna5']).mean()

# %%
df.groupby('coluna1').mean()
# Out:
# <ipython-input-178-a92cd97d84dc>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('coluna1').mean()
#           coluna2   coluna3     coluna4
# coluna1
# 45       1.000000  0.000000  227.000000
# 50       1.000000  0.000000  229.666667
# 51       1.000000  0.000000  231.000000
# 52       1.000000  0.000000  233.500000
# 53       1.400000  0.600000  256.000000
# 54       2.000000  1.000000  235.000000
# 55       2.000000  1.000000  268.333333
# 56       2.000000  1.000000  232.250000
# 58       2.000000  1.000000  222.500000
# 59       2.000000  1.000000  287.000000
# 60       2.000000  1.000000  270.000000
# 61       2.000000  1.000000  265.000000
# 62       2.000000  1.666667  273.333333
# 64       2.000000  2.000000  327.000000
# 65       3.000000  1.000000  325.600000
# ...

# %%
import numpy as np

# cópia de df
df_iris = df

# Gera dados faltante no dataset
for col in df_iris.columns[:-1]:
    df_iris.loc[np.random.choice(df_iris.index, 5), col] = np.nan

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   coluna1  97 non-null     float64
#  1   coluna2  97 non-null     float64
#  2   coluna3  97 non-null     float64
#  3   coluna4  97 non-null     float64
#  4   coluna5  102 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 4.1+ KB

# %%
df_iris.isnull().sum()
# Out:
# coluna1    5
# coluna2    5
# coluna3    5
# coluna4    5
# coluna5    0
# dtype: int64

# %%
df_iris.dropna(axis=0, inplace=True)

# %%
for col in df_iris.columns[:-1]:
    mean_val = df_iris[col].mean()
    df_iris[col].fillna(mean_val, inplace=True)

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87 entries, 1 to 101
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   coluna1  87 non-null     float64
#  1   coluna2  87 non-null     float64
#  2   coluna3  87 non-null     float64
#  3   coluna4  87 non-null     float64
#  4   coluna5  87 non-null     object
# dtypes: float64(4), object(1)
# memory usage: 4.1+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
grouped = df_iris.groupby('coluna2')['coluna1'].mean()
grouped.plot(kind='line', marker='o')


plt.title('Média do Comprimento da Sépala por Espécie')
plt.ylabel('Comprimento da Sépala (cm)')
plt.grid(True)
plt.show()

# %%
species_count = df['coluna1'].value_counts()
species_count.plot(kind='bar')

plt.title('Contagem de Espécies')
plt.xlabel('Espécie')
plt.ylabel('Contagem')
plt.show()

# %%
df.hist(bins=100, figsize=(15, 15))
plt.show()

# %%
plt.hist(df['coluna1'], bins=100)


plt.title('Histograma de Sepal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Contagem')
plt.show()

# %%
df.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False, figsize=(15, 15))
plt.show()

# %%
plt.scatter(df_iris['coluna1'], df_iris['coluna3'])

plt.title('Sepal Length vs Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.show()

# %%
colors = {'Iris-setosa':'red', 'Iris-versicolor':'blue', 'Iris-virginica':'green'}

# Verifica se todos os valores em df['coluna2'] estão presentes nas chaves do dicionário colors
if not df['coluna2'].isin(colors.keys()).all():
    # Se houver valores em df['coluna2'] que não correspondam às chaves do dicionário colors,
    # defina uma cor padrão para esses valores
    default_color = 'black'
    colors = df['coluna2'].map(colors).fillna(default_color)

plt.scatter(df['coluna1'], df['coluna3'], c=colors, label=colors)

plt.title('Sepal Length vs Petal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend(handles=[plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10) for color in colors.unique()], labels=colors.unique())
plt.show()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df,figsize=(15, 15))

plt.show()

# %%
import seaborn as sns

# A cor vem do campo `species` do dataframe

sns.pairplot(df, hue='coluna2', height=5)

plt.show()

# %%
# Violin plot
g = sns.violinplot(y='coluna2', x='coluna1', data=df, inner='quartile')
plt.show()
g = sns.violinplot(y='coluna2', x='coluna1', data=df, inner='quartile')
plt.show()
g = sns.violinplot(y='coluna2', x='coluna3', data=df, inner='quartile')
plt.show()
g = sns.violinplot(y='coluna2', x='coluna3', data=df, inner='quartile')
plt.show()

# %%
cols = ['coluna1', 'coluna1', 'coluna3','coluna3']
corr_matx = df[cols].corr()

heatmap = sns.heatmap(corr_matx,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size': 15},yticklabels=cols,xticklabels=cols,cmap='Dark2')

# %%
df['coluna1'].head()
# Out:
# 1    50.0
# 2    50.0
# 3    50.0
# 4    51.0
# 5    51.0
# Name: coluna1, dtype: float64

# %%
df[['coluna1']].head()
# Out:
#    coluna1
# 1     50.0
# 2     50.0
# 3     50.0
# 4     51.0
# 5     51.0

# %%
# Mostra as colunas petal_length e petal_width
df[['coluna1', 'coluna1']].head()
# Out:
#    coluna1  coluna1
# 1     50.0     50.0
# 2     50.0     50.0
# 3     50.0     50.0
# 4     51.0     51.0
# 5     51.0     51.0

# %%
df['coluna1'] = df['coluna1'] * df['coluna1']

df.head()
# Out:
#    coluna1  coluna2  coluna3  coluna4 coluna5
# 1   2500.0      1.0      0.0    239.0       D
# 2   2500.0      1.0      0.0    270.0       D
# 3   2500.0      1.0      0.0    180.0       D
# 4   2601.0      1.0      0.0    249.0       D
# 5   2601.0      1.0      0.0    249.0       D

# %%
## Insira seu código parte 2 aqui
## Usar como base aula 2

# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

# URL do arquivo CSV
url = "/content/apartamento-full.csv"

# Definição dos nomes das colunas
header = ['coluna1', 'coluna2', 'coluna3', 'coluna4', 'coluna5']

# Lê e carrega o arquivo para a memória
df = pd.read_csv(url, header=None, names=header)

# %%
df.head()
# Out:
#    coluna1  coluna2  coluna3  coluna4 coluna5
# 0       45        1        0      227       D
# 1       50        1        0      239       D
# 2       50        1        0      270       D
# 3       50        1        0      180       D
# 4       51        1        0      249       D

# %%
df.tail()
# Out:
#      coluna1  coluna2  coluna3  coluna4 coluna5
# 97       140        5        2      600       A
# 98       148        5        2      550       A
# 99       150        5        2      825       A
# 100      152        5        3      840       A
# 101      156        5        3      865       A

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   coluna1  102 non-null    int64
#  1   coluna2  102 non-null    int64
#  2   coluna3  102 non-null    int64
#  3   coluna4  102 non-null    int64
#  4   coluna5  102 non-null    object
# dtypes: int64(4), object(1)
# memory usage: 4.1+ KB

# %%
print(df.groupby('coluna2').size())
# Out:
# coluna2
# 1    12
# 2    29
# 3    39
# 4    15
# 5     7
# dtype: int64

# %%
entradas = df[['coluna1', 'coluna1']]
classes = df['coluna2']
print(f"Formato das tabelas de dados {entradas.shape} e classes {classes.shape}")
# Out:
# Formato das tabelas de dados (102, 2) e classes (102,)

# %%
# Separamos 20% para o teste
from sklearn.model_selection import train_test_split

entradas_treino, entradas_teste, classes_treino, classes_teste = train_test_split(entradas, classes, test_size=0.5)

print(f"Formato das tabelas de dados de treino {entradas_treino.shape} e teste {entradas_teste.shape}")
# Out:
# Formato das tabelas de dados de treino (51, 2) e teste (51, 2)

# %%
entradas_treino.head()
# Out:
#     coluna1  coluna1
# 38       65       65
# 29       60       60
# 82      106      106
# 6        51       51
# 32       62       62

# %%
classes_treino.head()
# Out:
# 38    3
# 29    2
# 82    4
# 6     1
# 32    2
# Name: coluna2, dtype: int64

# %%
# Importa a biblioteca
from sklearn.neighbors import KNeighborsClassifier

# Cria o classificar KNN
k = 9
modelo = KNeighborsClassifier(n_neighbors=k)

# Cria o modelo de machine learning
modelo.fit(entradas_treino, classes_treino)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
# Para obter as previsões, basta chamar o método predict()
classes_encontradas = modelo.predict(entradas_teste)
print("Predição: {}".format(classes_encontradas))
# Out:
# Predição: [2 5 3 2 1 3 2 3 3 3 2 2 1 4 4 3 3 2 2 3 2 1 3 3 2 4 1 1 3 1 1 3 3 3 3 2 3
#  4 1 2 3 2 3 4 1 4 1 4 3 2 4]

# %%
from sklearn.metrics import accuracy_score
acertos = accuracy_score(classes_teste, classes_encontradas)
print("Acerto médio de classificação: ", acertos)
# Out:
# Acerto médio de classificação:  0.7647058823529411

# %%
modelo.predict([[3.6, 2.8]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# Unificamos os dados de entrada e as classes de treino e teste em um daframe cada
df_treino = pd.concat((entradas_treino, classes_treino), axis=1)

novas_classes = pd.Series(classes_encontradas, name="coluna2", index=entradas_teste.index)
df_teste = pd.concat((entradas_teste, novas_classes), axis=1)

# %%
#### Resposta loop for para diferntes k
k_range = list(range(1,26))
acertos = []
for k in k_range:
    modelo = KNeighborsClassifier(n_neighbors=k)
    modelo.fit(entradas_treino, classes_treino)
    classes_encontradas = modelo.predict(entradas_teste)
    acertos.append(accuracy_score(classes_teste, classes_encontradas))


plt.plot(k_range, acertos)
plt.xlabel('Valor de k do KNN')
plt.ylabel('Taxa de acertos')
plt.title('Taxa de acertos x valor de k do KNN')
plt.show()

# %% [markdown]
# ## Pergunta 1: Em suas palavras o que são dataframes?

# %% [markdown]
# Dataframes são como planilhas superpoderosas para organizar e analisar dados

# %% [markdown]
# ## Pergunta 2: Em suas palavras o que é um algoritmo de classificação?

# %% [markdown]
# Algoritmos de classificação organizam dados em diferentes categorias

# %% [markdown]
# ## Pergunta 3: Em suas palavras e com base no que foi visto em aula como se avalia o resultado da classificação?

# %% [markdown]
# Diversas medidas podem ser usadas para avaliar o resultado da classificação

# %% [markdown]
# ## Pergunta 4: Em suas palavras o que é um algoritmo de regressão?

# %% [markdown]
# A fórmula pode ser usada para prever valores e entender a relação entre as variáveis
